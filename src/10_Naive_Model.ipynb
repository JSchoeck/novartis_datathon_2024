# %% [markdown]
# # Naive Predictor
#
# Simply set all target values to 1

# %%
import os

import IPython

import utils
from models.models import Naive

root = IPython.get_ipython().starting_dir  # type: ignore

os.chdir(root)
os.chdir("..")

# %%
df_pred = utils.load_data("predict")
df_pred.head(3)
# Out:
# 2024-11-28 23:53:32,732 - INFO - utils:	=== Loading predict data from d:\Nextcloud\GitHub\novartis_datathon_2024\novartis_datathon_2024\data\input\submission_data.csv
#         brand  che_pc_usd  che_perc_gdp               cluster_nl corporation  \
# 0  BRAND_E57A    2.079046       1.46792  BRAND_E57A_COUNTRY_06E4   CORP_01C7
# 1  BRAND_014B    2.079046       1.46792  BRAND_014B_COUNTRY_06E4   CORP_01C7
# 2  BRAND_1E6F    1.018268       1.10803  BRAND_1E6F_COUNTRY_4647   CORP_01C7
#
#         country launch_date        date       drug_id      ind_launch_date  \
# 0  COUNTRY_06E4  2022-02-01  2023-01-01  DRUG_ID_FADD  2022-08-01 00:00:00
# 1  COUNTRY_06E4  2022-09-01  2023-01-01  DRUG_ID_E07F                   -1
# 2  COUNTRY_4647  2022-05-01  2023-01-01  DRUG_ID_1A21  2022-06-01 00:00:00
#
#                  indication  insurance_perc_che  population  prev_perc  \
# 0              ['IND_C3B6']            1.000000    1.004739   0.036647
# ...

# %%
df_pred = utils.predict_submission_data(Naive())
df_pred.head(3)
# Out:
# 2024-11-28 23:53:33,860 - INFO - utils:	=== Loading predict data from d:\Nextcloud\GitHub\novartis_datathon_2024\novartis_datathon_2024\data\input\submission_data.csv
# 2024-11-28 23:53:33,869 - INFO - utils:	=== Adding predictions to submission data.
#         brand  che_pc_usd  che_perc_gdp               cluster_nl corporation  \
# 0  BRAND_E57A    2.079046       1.46792  BRAND_E57A_COUNTRY_06E4   CORP_01C7
# 1  BRAND_014B    2.079046       1.46792  BRAND_014B_COUNTRY_06E4   CORP_01C7
# 2  BRAND_1E6F    1.018268       1.10803  BRAND_1E6F_COUNTRY_4647   CORP_01C7
#
#         country launch_date        date       drug_id      ind_launch_date  \
# 0  COUNTRY_06E4  2022-02-01  2023-01-01  DRUG_ID_FADD  2022-08-01 00:00:00
# 1  COUNTRY_06E4  2022-09-01  2023-01-01  DRUG_ID_E07F                   -1
# 2  COUNTRY_4647  2022-05-01  2023-01-01  DRUG_ID_1A21  2022-06-01 00:00:00
#
#                  indication  insurance_perc_che  population  prev_perc  \
# ...

# %%
utils.save_submission_file(df_pred)
# Out:
# 2024-11-28 23:53:36,146 - INFO - utils:	=== Saving submission file to d:\Nextcloud\GitHub\novartis_datathon_2024\novartis_datathon_2024\data\output\submission_attempt_4.csv
